# %%
import glob
import pandas as pd

# %%
EnTAP_annot = pd.read_table("../EnTAP/entap_outfiles/ontology/EggNOG_DMND/processed/annotated_sequences_lvl0.tsv", header=0)
EnTap_unannot = pd.read_table("../EnTAP/entap_outfiles/ontology/EggNOG_DMND/processed/unannotated_sequences_lvl0.tsv", header=0)
EnTAP_besthits = pd.read_table("../EnTAP/entap_outfiles/similarity_search/DIAMOND/overall_results/best_hits_lvl0.tsv", header=0)

# %%
EnTAP_annot
# Out:
#                   Query Sequence            Seed Ortholog   Seed E-Value  \
# 0      TRINITY_DN148495_c0_g1_i1  9615.ENSCAFP00000006056   1.200000e-12
# 1      TRINITY_DN148451_c0_g1_i1        6669.DappuP312237   1.000000e-08
# 2      TRINITY_DN148486_c0_g1_i1          7460.GB14876-PA   6.700000e-38
# 3      TRINITY_DN148427_c0_g1_i1       3711.Bra030501.1-P   7.500000e-31
# 4      TRINITY_DN148416_c0_g1_i1       6945.ISCW004507-PA   4.000000e-22
# ...                          ...                      ...            ...
# 27755    TRINITY_DN7744_c2_g1_i1        6669.DappuP219239   5.900000e-07
# 27756  TRINITY_DN150385_c0_g1_i1          7460.GB11737-PA   1.300000e-11
# 27757   TRINITY_DN20239_c0_g1_i1         7070.TC002995-PA  6.300000e-164
# 27758  TRINITY_DN150310_c0_g1_i1    6183.Smp_080740__mRNA   1.900000e-33
# 27759  TRINITY_DN117838_c0_g1_i1           7739.JGI234412   2.000000e-06
#
#        Seed Score Predicted Gene      Tax Scope Tax Scope Max  \
# ...

# %%
EnTap_unannot
# Out:
#                    Query Sequence  Seed Ortholog  Seed E-Value  Seed Score  \
# 0       TRINITY_DN148438_c0_g1_i1            NaN           NaN         NaN
# 1       TRINITY_DN148402_c0_g1_i1            NaN           NaN         NaN
# 2       TRINITY_DN148485_c0_g1_i1            NaN           NaN         NaN
# 3       TRINITY_DN148410_c0_g1_i1            NaN           NaN         NaN
# 4       TRINITY_DN148465_c0_g1_i1            NaN           NaN         NaN
# ...                           ...            ...           ...         ...
# 122188  TRINITY_DN120264_c0_g1_i1            NaN           NaN         NaN
# 122189  TRINITY_DN120281_c0_g1_i1            NaN           NaN         NaN
# 122190  TRINITY_DN120271_c0_g1_i1            NaN           NaN         NaN
# 122191  TRINITY_DN120257_c0_g1_i1            NaN           NaN         NaN
# 122192  TRINITY_DN120200_c0_g1_i1            NaN           NaN         NaN
#
# ...

# %%
EnTAP_besthits
# Out:
#                   Query Sequence                Subject Sequence  \
# 0      TRINITY_DN148451_c0_g1_i1  tr|A0A5B7D5G9|A0A5B7D5G9_PORTR
# 1      TRINITY_DN148486_c0_g1_i1                  XP_018018011.1
# 2      TRINITY_DN148427_c0_g1_i1  tr|A0A1B6DKL7|A0A1B6DKL7_9HEMI
# 3      TRINITY_DN148400_c0_g1_i1                      ODM87636.1
# 4      TRINITY_DN148499_c0_g1_i1              sp|Q6AYK6|CYBP_RAT
# ...                          ...                             ...
# 19963   TRINITY_DN15519_c0_g1_i1  tr|A0A5B7CI35|A0A5B7CI35_PORTR
# 19964  TRINITY_DN100337_c0_g1_i1           sp|Q2KIB5|VA0E2_BOVIN
# 19965   TRINITY_DN12189_c0_g1_i1                  XP_009860916.2
# 19966  TRINITY_DN150385_c0_g1_i1                  XP_026753423.1
# 19967  TRINITY_DN150310_c0_g1_i1                      EOB02401.1
#
#        Percent Identical  Alignment Length  Mismatches  Gap Openings  \
# 0                   89.6               115          12             0
# ...

# %%
# Out:
#                   Query Sequence                Subject Sequence  \
# 0      TRINITY_DN148451_c0_g1_i1  tr|A0A5B7D5G9|A0A5B7D5G9_PORTR
# 1      TRINITY_DN148486_c0_g1_i1                  XP_018018011.1
# 2      TRINITY_DN148427_c0_g1_i1  tr|A0A1B6DKL7|A0A1B6DKL7_9HEMI
# 3      TRINITY_DN148400_c0_g1_i1                      ODM87636.1
# 4      TRINITY_DN148499_c0_g1_i1              sp|Q6AYK6|CYBP_RAT
# ...                          ...                             ...
# 19963   TRINITY_DN15519_c0_g1_i1  tr|A0A5B7CI35|A0A5B7CI35_PORTR
# 19964  TRINITY_DN100337_c0_g1_i1           sp|Q2KIB5|VA0E2_BOVIN
# 19965   TRINITY_DN12189_c0_g1_i1                  XP_009860916.2
# 19966  TRINITY_DN150385_c0_g1_i1                  XP_026753423.1
# 19967  TRINITY_DN150310_c0_g1_i1                      EOB02401.1
#
#                                              Description  \
# 0      tr|A0A5B7D5G9|A0A5B7D5G9_PORTR Uncharacterized...
# 1      XP_018018011.1 PREDICTED: uncharacterized prot...
# ...
