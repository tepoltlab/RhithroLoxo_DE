# %% [markdown]
# ### WGCNA

# %% [markdown]
# Looking for modules of coexpressed transcripts in the variance stabilized transformed count data from `DESeq2` and relating them to trait data (i.e. infection status, range, etc.). Here are some good resources for learning more about how to apply WGCNA to our data set:
#
# [WGCNA tutorials](https://horvath.genetics.ucla.edu/html/CoexpressionNetwork/Rpackages/WGCNA/Tutorials/)
#
# [Harvard WGCNA walkthrough](http://pklab.med.harvard.edu/scw2014/WGCNA.html)
#
# Peter Langfelder blog posts: [categorical data](https://peterlangfelder.com/2018/11/25/working-with-categorical-variables/), [signed vs. unsigned](https://peterlangfelder.com/2018/11/25/signed-or-unsigned-which-network-type-is-preferable/), [signed vs. signed hybrid](https://peterlangfelder.com/2018/11/25/__trashed/)
#
# [Matz lab code](https://github.com/sbarfield/tagSeq-commonGarden/blob/master/WGCNA_common_garden.r)

# %% [markdown]
# If you have already performed module construction (steps `adjacency()`, `TOMsimilarity()`, and `flashClust()`) and saved the output (`dissTOM` and `geneTree`), you can skip all steps through module construction and load in saved objects for downstream use.

# %% [markdown]
# Load in the package.

# %%
library(WGCNA)
options(stringsAsFactors = FALSE)
# Out:
# Loading required package: dynamicTreeCut
# Loading required package: fastcluster
#
# Attaching package: ‘fastcluster’
#
# The following object is masked from ‘package:stats’:
#
#     hclust
#
#
#
# Attaching package: ‘WGCNA’
#
# The following object is masked from ‘package:stats’:
#
#     cor

# %% [markdown]
# ## Infected vs. uninfected
#
# At this stage, we'll just do bulk comparisons between parasitized and control, using the transformed counts that include the FP samples.

# %% [markdown]
# Read in the data.

# %%
vsd <- read.table("../outputs/WGCNA_noFP_in.tsv", sep="\t")

# %% [markdown]
# Take a look.

# %%
head(vsd)
dim(vsd)
# Out:
#                           AP_C_1   AP_C_2   AP_C_3   AP_C_4   AP_C_5   AP_P_1
# TRINITY_DN38930_c0_g1_i1  6.561640 7.280746 6.257657 6.073251 6.058873 6.356266
# TRINITY_DN27848_c0_g1_i1  5.397401 6.458467 5.169869 5.579711 6.267623 4.446448
# TRINITY_DN134395_c0_g1_i1 6.728020 6.871943 4.036483 4.065251 5.431370 3.686827
# TRINITY_DN144418_c0_g1_i1 6.774381 7.442585 5.536740 6.866948 7.152390 5.644150
# TRINITY_DN25283_c0_g1_i1  4.974734 5.234632 5.365563 5.548207 5.537313 5.403693
# TRINITY_DN21478_c0_g1_i1  5.028829 7.240662 6.497841 7.283586 6.986277 8.163789
#                           AP_P_2   AP_P_3   AP_P_6   LA_C_1   ... NJ_P_7
# TRINITY_DN38930_c0_g1_i1  6.344543 6.881363 6.276478 8.408588 ... 6.324693
# TRINITY_DN27848_c0_g1_i1  5.838175 2.734490 6.044118 3.967923 ... 4.925365
# TRINITY_DN134395_c0_g1_i1 2.734490 3.935163 2.734490 5.363759 ... 4.282344
# TRINITY_DN144418_c0_g1_i1 6.661436 4.185836 7.742220 3.844064 ... 7.199258
# TRINITY_DN25283_c0_g1_i1  5.166006 5.376271 5.659351 4.764785 ... 5.290461
# TRINITY_DN21478_c0_g1_i1  8.518071 6.155257 8.681083 6.546286 ... 6.056616
#                           SC_C_12  SC_C_14  SC_C_2   SC_C_6   SC_C_7   SC_C_9
# TRINITY_DN38930_c0_g1_i1  5.613551 6.271771 6.954202 5.678067 5.845178 5.865745
# TRINITY_DN27848_c0_g1_i1  5.634905 5.451417 4.988461 5.551289 5.525427 5.628204
# TRINITY_DN134395_c0_g1_i1 3.665181 6.241096 5.270637 3.392644 5.716996 3.777396
# TRINITY_DN144418_c0_g1_i1 7.288908 5.113375 5.320628 6.595488 5.575851 6.963687
# TRINITY_DN25283_c0_g1_i1  5.454097 6.128190 5.415435 5.283518 5.418701 5.341524
# TRINITY_DN21478_c0_g1_i1  6.144496 6.919233 7.687244 6.379222 7.988267 7.935728
#                           SC_P_1   SC_P_2   SC_P_3
# TRINITY_DN38930_c0_g1_i1  6.144407 7.152954 6.121470
# TRINITY_DN27848_c0_g1_i1  5.774041 3.491369 5.737848
# TRINITY_DN134395_c0_g1_i1 3.256131 3.793275 4.310273
# TRINITY_DN144418_c0_g1_i1 7.391077 4.359176 6.608037
# TRINITY_DN25283_c0_g1_i1  5.971349 4.201626 5.424357
# TRINITY_DN21478_c0_g1_i1  7.239494 6.066087 7.822114
# [1] 43851    65

# %% [markdown]
# Looks good. Now let's transpose it.

# %%
vsd <- t(vsd)
vsd[1:6,1:6]
dim(vsd)
# Out:
#        TRINITY_DN38930_c0_g1_i1 TRINITY_DN27848_c0_g1_i1
# AP_C_1 6.561640                 5.397401
# AP_C_2 7.280746                 6.458467
# AP_C_3 6.257657                 5.169869
# AP_C_4 6.073251                 5.579711
# AP_C_5 6.058873                 6.267623
# AP_P_1 6.356266                 4.446448
#        TRINITY_DN134395_c0_g1_i1 TRINITY_DN144418_c0_g1_i1
# AP_C_1 6.728020                  6.774381
# AP_C_2 6.871943                  7.442585
# AP_C_3 4.036483                  5.536740
# AP_C_4 4.065251                  6.866948
# AP_C_5 5.431370                  7.152390
# AP_P_1 3.686827                  5.644150
#        TRINITY_DN25283_c0_g1_i1 TRINITY_DN21478_c0_g1_i1
# AP_C_1 4.974734                 5.028829
# AP_C_2 5.234632                 7.240662
# AP_C_3 5.365563                 6.497841
# AP_C_4 5.548207                 7.283586
# AP_C_5 5.537313                 6.986277
# AP_P_1 5.403693                 8.163789
# [1]    65 43851

# %% [markdown]
# Now we check to see if there are any genes or samples with too many missing values.

# %%
gsg = goodSamplesGenes(vsd, verbose = 3)
gsg$allOK
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE

# %% [markdown]
# Good. Now we'll cluster the samples to identify outliers.

# %%
tree = hclust(dist(vsd), method = "average");
plot(tree, main = "Sample clustering to detect outliers", sub="", xlab="", cex.lab = 1.5,
cex.axis = 1.5, cex.main = 2)
# Out:
# Plot with title “Sample clustering to detect outliers”

# %% [markdown]
# Nothing looks too out of the ordinary to get chucked out. Note that this count data already excludes the outliers we removed in DESeq2 (MA control crabs and AP_C_6)

# %% [markdown]
# *DO THIS LATER*
#
# Now we'll load in the sample metadata (same as coldata in DESeq2 analysis).

# %% [markdown]
# *IGNORE BELOW FOR NOW* Just sex and conditoin
#
# The data in this data.frame are all of class 'character' and represent categorical variables. WGCNA was originally constructed to look for correlations between expression modules and numeric trait data (i.e. levels of some disease biomarker, etc). Fortunately, the creators included functions to binarize combinations of categorical data so that we can compare among groups. We will use these later when looking more in depth at comparisons among specific combinations of variables (i.e. range and infection status). The initial comparison will be of just parasitized vs. uninfected, which, being binary, is easy to transform.  We'll subset the coldata to just include the condition and binarize it.

# %% [markdown]
# Okay looks good. Now we'll have a look at the tree with the infection state colored across samples.

# %%
#tree2 = hclust(dist(vsd), method = "average")
#traitColors = numbers2colors(coldata_PvC, signed = FALSE)
#plotDendroAndColors(tree2,
#    main = "Sample dendrogram and trait heatmap")
# Out:
# Error in plotDendroAndColors(tree2, main = "Sample dendrogram and trait heatmap"): argument "colors" is missing, with no default
# Traceback:
#
# 1. plotDendroAndColors(tree2, main = "Sample dendrogram and trait heatmap")

# %% [markdown]
# Again, as we saw earlier, the samples don't cluster according to infection status when starting from a distance matrix created from the entire matrix of counts. There is just so much other variation present in the data that infection status doesn't stand out so much. This analysis should help resolve which co-expressed groups of transcripts are related to infection status.
#
# Now we're set up, let's start the actually calculations. First we'll enable multi-threading.

# %%
enableWGCNAThreads()
# Out:
# Allowing parallel execution with up to 35 working processes.

# %% [markdown]
# Then we'll start with actually performing these calculations. Note that these requires a lot of memory. Make sure to request as much memory as possible when starting up your `srun` session. I requested 24 threads and 180gb RAM. Probably overkill, but I didn't get booted off the node.

# %%
sft = pickSoftThreshold(vsd, verbose = 5, networkType="signed")
# Out:
# pickSoftThreshold: will use block size 1020.
#  pickSoftThreshold: calculating connectivity for given powers...
#    ..working on genes 1 through 1020 of 43851
#    ..working on genes 1021 through 2040 of 43851
#    ..working on genes 2041 through 3060 of 43851
#    ..working on genes 3061 through 4080 of 43851
#    ..working on genes 4081 through 5100 of 43851
#    ..working on genes 5101 through 6120 of 43851
#    ..working on genes 6121 through 7140 of 43851
#    ..working on genes 7141 through 8160 of 43851
#    ..working on genes 8161 through 9180 of 43851
#    ..working on genes 9181 through 10200 of 43851
#    ..working on genes 10201 through 11220 of 43851
#    ..working on genes 11221 through 12240 of 43851
#    ..working on genes 12241 through 13260 of 43851
#    ..working on genes 13261 through 14280 of 43851
#    ..working on genes 14281 through 15300 of 43851
#    ..working on genes 15301 through 16320 of 43851
#    ..working on genes 16321 through 17340 of 43851
#    ..working on genes 17341 through 18360 of 43851
#    ..working on genes 18361 through 19380 of 43851
#    ..working on genes 19381 through 20400 of 43851
#    ..working on genes 20401 through 21420 of 43851
#    ..working on genes 21421 through 22440 of 43851
#    ..working on genes 22441 through 23460 of 43851
#    ..working on genes 23461 through 24480 of 43851
#    ..working on genes 24481 through 25500 of 43851
#    ..working on genes 25501 through 26520 of 43851
#    ..working on genes 26521 through 27540 of 43851
#    ..working on genes 27541 through 28560 of 43851
#    ..working on genes 28561 through 29580 of 43851
#    ..working on genes 29581 through 30600 of 43851
#    ..working on genes 30601 through 31620 of 43851
#    ..working on genes 31621 through 32640 of 43851
#    ..working on genes 32641 through 33660 of 43851
#    ..working on genes 33661 through 34680 of 43851
#    ..working on genes 34681 through 35700 of 43851
#    ..working on genes 35701 through 36720 of 43851
#    ..working on genes 36721 through 37740 of 43851
#    ..working on genes 37741 through 38760 of 43851
#    ..working on genes 38761 through 39780 of 43851
#    ..working on genes 39781 through 40800 of 43851
#    ..working on genes 40801 through 41820 of 43851
#    ..working on genes 41821 through 42840 of 43851
#    ..working on genes 42841 through 43851 of 43851
#    Power SFT.R.sq slope truncated.R.sq mean.k. median.k. max.k.
# 1      1    0.727  3.92          0.690   22200   22300.0  24300
# 2      2    0.510 -3.00          0.447   12700   11900.0  16900
# 3      3    0.750 -2.13          0.687    7980    7230.0  13100
# 4      4    0.866 -1.70          0.830    5340    4630.0  10700
# 5      5    0.892 -1.48          0.876    3770    3090.0   9080
# 6      6    0.893 -1.37          0.893    2770    2120.0   7870
# 7      7    0.888 -1.31          0.899    2100    1490.0   6930
# 8      8    0.883 -1.29          0.901    1640    1060.0   6170
# 9      9    0.878 -1.28          0.904    1310     768.0   5540
# 10    10    0.881 -1.27          0.914    1070     566.0   5010
# 11    12    0.873 -1.28          0.917     735     326.0   4160
# 12    14    0.869 -1.30          0.925     529     195.0   3520
# 13    16    0.876 -1.31          0.939     393     120.0   3010
# 14    18    0.876 -1.33          0.945     300      75.1   2600
# 15    20    0.875 -1.35          0.949     233      48.2   2270

# %%
plot(sft$fitIndices[,1], -sign(sft$fitIndices[,3])*sft$fitIndices[,2],
    xlab="Soft Threshold (power)",ylab="Scale Free Topology Model Fit,signed R^2",type="n",
    main = paste("Scale independence"))
text(sft$fitIndices[,1], -sign(sft$fitIndices[,3])*sft$fitIndices[,2],
    labels=c(seq(1, 10, by = 1), seq(12, 20, by = 2)),col="red") #labels from default for power vector
abline(h=0.90,col="red")
plot(sft$fitIndices[,1], sft$fitIndices[,5],
    xlab="Soft Threshold (power)",ylab="Mean Connectivity", type="n",
    main = paste("Mean connectivity"))
    text(sft$fitIndices[,1], sft$fitIndices[,5], labels=c(seq(1, 10, by = 1), seq(12, 20, by = 2)), col="red")
# Out:
# Plot with title “Scale independence”
# Plot with title “Mean connectivity”

# %% [markdown]
# We are going to pick a power of 6, as it is the first value to reach the plateau at ~0.9, as [recommended](https://horvath.genetics.ucla.edu/html/CoexpressionNetwork/Rpackages/WGCNA/Tutorials/FemaleLiver-02-networkConstr-auto.pdf). It's also the highest value overall, as the $r^{2}$ drops after a power of 6.
#
# Now we'll do the module construction.

# %%
library(flashClust)
adjacency = adjacency(vsd, power = 6,type="signed")
TOM = TOMsimilarityFromExpr(vsd,networkType = "signed", TOMType = "signed", power = 6)
dissTOM = 1-TOM
geneTree = flashClust(as.dist(dissTOM),method="average")
save(dissTOM,geneTree,file="signedDissTOM_tree_noFP.RData")
# Out:
# Attaching package: ‘flashClust’
#
# The following object is masked from ‘package:fastcluster’:
#
#     hclust
#
# The following object is masked from ‘package:stats’:
#
#     hclust

# %%
minModuleSize = 20;
# Module identification using dynamic tree cut:
dynamicMods = cutreeDynamic(dendro = geneTree, distM = dissTOM,
deepSplit = 4, pamRespectsDendro = FALSE,
minClusterSize = minModuleSize);
table(dynamicMods)
dynamicColors = labels2colors(dynamicMods)

# %%
MEList = moduleEigengenes(vsd, colors = dynamicColors)
MEs = MEList$eigengenes
# Calculate dissimilarity of module eigengenes
MEDiss = 1-cor(MEs);
METree = flashClust(as.dist(MEDiss), method = "average");

save(dynamicMods,dynamicColors,MEs,METree,geneTree,file="1stPassModules_noFP.RData")

# %%
load(file="1stPassModules_noFP.RData")

# %%
plotDendroAndColors(geneTree, dynamicColors,
c("Dynamic Tree Cut"),
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)

# %%
#sizeGrWindow(7, 6)
plot(METree, main = "Clustering of module eigengenes",
xlab = "", sub = "")
MEDissThres = 0.1
# Plot the cut line into the dendrogram
abline(h=MEDissThres, col = "red")

# %%
merge = mergeCloseModules(vsd, dynamicColors, cutHeight = MEDissThres, verbose = 3)
# The merged module colors
mergedColors = merge$colors;
# Eigengenes of the new merged modules:
mergedMEs = merge$newMEs

# %%
plotDendroAndColors(geneTree, cbind(dynamicColors, mergedColors),
c("Dynamic Tree Cut", "Merged dynamic"),
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)

# %%
moduleColors = mergedColors
# Construct numerical labels corresponding to the colors
colorOrder = c("grey", standardColors(50));
moduleLabels = match(moduleColors, colorOrder)-1;
MEs = mergedMEs;

# %%
MEDiss = 1-cor(MEs);
# Cluster module eigengenes
METree = flashClust(as.dist(MEDiss), method = "average");
# Plot the result
plot(METree, main = "Clustering of module eigengenes",
xlab = "", sub = "")

# %%
table(moduleColors)

# %%
save(MEs, geneTree, moduleLabels, moduleColors, file = "networkdata_signed_noFP.RData")

# %% [markdown]
# ## Trait data correlations

# %%
coldata <- read.table("../metadata/DESeq2_coldata.txt", row.names=1, col.names=c("","site","condition","range","sex"), stringsAsFactors = FALSE)
coldata <- coldata[rownames(vsd),]
coldata$sex.condition <- paste(coldata$sex, coldata$condition)
head(coldata)
dim(coldata)
# Out:
#        site condition range  sex sex.condition
# AP_C_1 AP   C         Native F   F C
# AP_C_2 AP   C         Native F   F C
# AP_C_3 AP   C         Native M   M C
# AP_C_4 AP   C         Native M   M C
# AP_C_5 AP   C         Native M   M C
# AP_P_1 AP   P         Native F   F P
# [1] 77  5

# %%
coldata <- binarizeCategoricalColumns(coldata, 
      convertColumns = c("condition","sex","sex.condition"), 
      includePairwise = TRUE, includeLevelVsAll = FALSE)
#coldata <- binarizeCategoricalColumns(coldata, 
#      convertColumns = c("sex.condition"), 
#      includePairwise = FALSE, includeLevelVsAll = TRUE)
head(coldata)
# Out:
#        site condition.P.vs.C range  sex.M.vs.F sex.condition.F P.vs.F C
# AP_C_1 AP   0                Native 0           0
# AP_C_2 AP   0                Native 0           0
# AP_C_3 AP   0                Native 1          NA
# AP_C_4 AP   0                Native 1          NA
# AP_C_5 AP   0                Native 1          NA
# AP_P_1 AP   1                Native 0           1
#        sex.condition.M C.vs.F C sex.condition.M P.vs.F C
# AP_C_1  0                        0
# AP_C_2  0                        0
# AP_C_3  1                       NA
# AP_C_4  1                       NA
# AP_C_5  1                       NA
# AP_P_1 NA                       NA
#        sex.condition.M C.vs.F P sex.condition.M P.vs.F P
# AP_C_1 NA                       NA
# AP_C_2 NA                       NA
# AP_C_3  1                       NA
# AP_C_4  1                       NA
# AP_C_5  1                       NA
# AP_P_1  0                        0
#        sex.condition.M P.vs.M C
# AP_C_1 NA
# AP_C_2 NA
# AP_C_3  0
# AP_C_4  0
# AP_C_5  0
# AP_P_1 NA

# %%
# Define numbers of genes and samples
nGenes = ncol(vsd);
nSamples = nrow(vsd);
# Recalculate MEs with color labels
MEs0 = moduleEigengenes(vsd, moduleColors)$eigengenes
MEs = orderMEs(MEs0)
moduleTraitCor = cor(MEs, coldata, use = "p");
moduleTraitPvalue = corPvalueStudent(moduleTraitCor, nSamples);
# Out:
# Warning message in storage.mode(y) <- "double":
# “NAs introduced by coercion”

# %%
# correlations of genes with eigengenes
moduleGeneCor=cor(MEs,vsd)
moduleGenePvalue = corPvalueStudent(moduleGeneCor, nSamples);

moduleTraitCor = cor(MEs, coldata, use = "p");
moduleTraitPvalue = corPvalueStudent(moduleTraitCor, nSamples);
# Out:
# Warning message in storage.mode(y) <- "double":
# “NAs introduced by coercion”

# %%
# Will display correlations and their p-values
textMatrix = paste(signif(moduleTraitCor, 2), "\n(",
signif(moduleTraitPvalue, 1), ")", sep = "");
dim(textMatrix) = dim(moduleTraitCor)
par(mar = c(6, 8.5, 3, 3));
# Display the correlation values within a heatmap plot
labeledHeatmap(Matrix = moduleTraitCor,
xLabels = names(coldata),
yLabels = names(MEs),
ySymbols = names(MEs),
colorLabels = FALSE,
colors = greenWhiteRed(50),
textMatrix = textMatrix,
setStdMargins = FALSE,
cex.text = 0.5,
zlim = c(-1,1),
main = paste("Module-trait relationships"))
# Out:
# Warning message in greenWhiteRed(50):
# “WGCNA::greenWhiteRed: this palette is not suitable for people
# with green-red color blindness (the most common kind of color blindness).
# Consider using the function blueWhiteRed instead.”
# Plot with title “Module-trait relationships”

# %% [markdown]
# MEgreenyellow shows extreme overexpression in parasitized males compared to uninfected males. It also shows underexpression in control males compared to control females. Notably, not different between infected males and infected females or infected males and control females. Significant between males and females overall and between parasitized and control overall. The latter could be due to sex ratio in experiment overall?
#
# Magenta shows a similar pattern as well.

# %% [markdown]
# Clear environment for easy loading next time.

# %%
rm(list = ls())

# %% [markdown]
# We're going to want to have a column that indicates the combination of range and condition.
#
# USE PASTE!
